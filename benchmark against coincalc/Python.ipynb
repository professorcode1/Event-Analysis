# %%
from EventAnalysis import EventAnalysis
import pandas as pd
from datetime import timedelta

# %%
monsoonEventDf = pd.read_csv("monsoonEventDf.csv", index_col="DateTime", parse_dates=[0]) > 0

# %%
# Out:
#             X76.5Y8.5  X77.5Y8.5  X78.5Y8.5  X76.5Y9.5  X77.5Y9.5  X78.5Y9.5  \
# DateTime
# 1901-01-01      False      False      False      False      False      False
# 1901-01-02      False      False      False      False      False      False
# 1901-01-03      False      False      False      False      False      False
# 1901-01-04      False      False      False      False      False      False
# 1901-01-05      False      False      False      False      False      False
# ...               ...        ...        ...        ...        ...        ...
# 2020-12-27      False      False      False      False      False      False
# 2020-12-28      False      False      False      False      False      False
# 2020-12-29      False      False      False      False      False      False
# 2020-12-30      False      False      False      False      False      False
# 2020-12-31      False      False      False      False      False      False
#
# ...

# %%
# %%time
EventAnalysis(monsoonEventDf.iloc[:,0:25]).ECA(timedelta(days=60))[0]
# Out:
# Time elapsed to run the computation :: 0.0 minutes 0 seconds
# CPU times: total: 375 ms
# Wall time: 398 ms
# Coordinates  X76.5Y8.5  X77.5Y8.5  X78.5Y8.5  X76.5Y9.5  X77.5Y9.5  X78.5Y9.5  \
# Coordinates
# X76.5Y8.5     1.000000   0.956522   0.911765   0.955504   0.725664   0.861111
# X77.5Y8.5     0.956522   1.000000   0.735294   0.962733   0.336283   0.453704
# X78.5Y8.5     0.911765   0.735294   1.000000   1.000000   0.941176   0.852941
# X76.5Y9.5     0.955504   0.962733   1.000000   1.000000   0.893805   0.981481
# X77.5Y9.5     0.725664   0.336283   0.941176   0.893805   1.000000   0.583333
# X78.5Y9.5     0.861111   0.453704   0.852941   0.981481   0.583333   1.000000
# X79.5Y9.5     0.947368   0.263158   0.508772   0.982456   0.719298   0.666667
# X75.5Y10.5    0.934426   0.925466   0.941176   0.959740   0.840708   0.962963
# X76.5Y10.5    0.903712   0.844720   1.000000   0.975058   0.893805   0.962963
# ...

# %%
# %%time
EventAnalysis(monsoonEventDf).ECA(timedelta(days=60))[0]
# Out:
# Time elapsed to run the computation :: 0.0 minutes 2 seconds
# CPU times: total: 13.6 s
# Wall time: 5.24 s
# Coordinates  X76.5Y8.5  X77.5Y8.5  X78.5Y8.5  X76.5Y9.5  X77.5Y9.5  X78.5Y9.5  \
# Coordinates
# X76.5Y8.5     1.000000   0.956522   0.911765   0.955504   0.725664   0.861111
# X77.5Y8.5     0.956522   1.000000   0.735294   0.962733   0.336283   0.453704
# X78.5Y8.5     0.911765   0.735294   1.000000   1.000000   0.941176   0.852941
# X76.5Y9.5     0.955504   0.962733   1.000000   1.000000   0.893805   0.981481
# X77.5Y9.5     0.725664   0.336283   0.941176   0.893805   1.000000   0.583333
# ...                ...        ...        ...        ...        ...        ...
# X73.5Y36.5    0.912214   0.341615   0.205882   0.980916   0.433628   0.407407
# X74.5Y36.5    0.917197   0.422360   0.176471   0.987261   0.300885   0.416667
# X75.5Y36.5    0.934389   0.422360   0.147059   0.995475   0.265487   0.379630
# ...
